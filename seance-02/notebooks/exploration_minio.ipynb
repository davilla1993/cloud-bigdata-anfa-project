# %%
# %pip install boto3==1.34.0
# Out:
# Requirement already satisfied: boto3==1.34.0 in /opt/conda/lib/python3.11/site-packages (1.34.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.0 in /opt/conda/lib/python3.11/site-packages (from boto3==1.34.0) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3==1.34.0) (1.1.0)
# Requirement already satisfied: s3transfer<0.10.0,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from boto3==1.34.0) (0.9.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.0->boto3==1.34.0) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.0->boto3==1.34.0) (2.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.0->boto3==1.34.0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3

# Note importante : depuis le conteneur Jupyter, MinIO est accessible
# par son nom de service "minio", PAS par "localhost".
# C'est la résolution DNS automatique du réseau Compose.
s3 = boto3.client(
    "s3",
    endpoint_url="http://minio:9000",
    aws_access_key_id="anfa-app-key",
    aws_secret_access_key="anfa-app-secret-2026",
    region_name="us-east-1",
)
# Vérifier la liste des buckets
s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '18BB61B372C3DB0D',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '366',
#    'content-type': 'application/xml',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18BB61B372C3DB0D',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '4401',
#    'x-ratelimit-remaining': '4401',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Mon, 22 Jun 2026 10:51:40 GMT'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'anfa-raw',
#    'CreationDate': datetime.datetime(2026, 6, 18, 11, 19, 53, 138000, tzinfo=tzlocal())}],
#  'Owner': {'DisplayName': 'minio',
#   'ID': '02d6176db174dc93cb1b899f7c6078f08654445fe8cf1b6ce98d8855f66bdbf4'}}

# %%
reponse = s3.list_objects_v2(Bucket="anfa-raw", Prefix="referentiel/")
for obj in reponse.get("Contents", []):
    print(f"{obj['Key']} ({obj['Size']} octets)")
# Out:
# referentiel/arrets.csv (3821 octets)
# referentiel/bus.csv (5912 octets)
# referentiel/lignes.csv (945 octets)
# referentiel/tarifs.csv (718 octets)

# %%
import pandas as pd
from io import BytesIO

# Télécharger le CSV des lignes en mémoire
obj = s3.get_object(Bucket="anfa-raw", Key="referentiel/lignes.csv")
df_lignes = pd.read_csv(BytesIO(obj["Body"].read()))

df_lignes
# Out:
#    ligne_id                            nom         terminus_depart  \
# 0       L01           Adidogomé - Adawlato      Adidogomé Assiyéyé
# 1       L02   Agoè Assiyéyé - Grand Marché  Agoè Assiyéyé Terminus
# 2       L03              Avédji - Adawlato        Avédji Limousine
# 3       L04  Université de Lomé - Adawlato    Campus Universitaire
# 4       L05         Hédzranawoé - Adawlato    Hédzranawoé Terminus
# 5       L06         Bè - Tokoin Casablanca                Bè Kpota
# 6       L07          Cacavéli - BIA Centre         Cacavéli Marché
# 7       L08        Aéroport GTA - Adawlato            Aéroport GTA
# 8       L09             Baguida - Adawlato        Baguida Terminus
# 9       L10    Anfamé - Université de Lomé         Anfamé Terminus
# 10      L11            Djidjolé - Adawlato       Djidjolé Terminus
# 11      L12         Kégué Stade - Adawlato          Stade de Kégué
#
#          terminus_arrivee  nb_arrets  distance_km
# 0         Adawlato Marché          9         9.89
# 1   Adawlato Grand Marché          9        16.28
# 2         Adawlato Marché          9        11.67
# 3         Adawlato Marché          8         5.65
# 4         Adawlato Marché          8         7.37
# 5       Tokoin Casablanca          7         5.49
# 6              BIA Centre          7        10.03
# 7         Adawlato Marché          7         8.73
# 8         Adawlato Marché          8        13.13
# 9    Campus Universitaire          8         5.89
# 10        Adawlato Marché          6         5.85
# 11        Adawlato Marché          7         8.45

# %%
# Top 3 des lignes les plus longues
df_lignes.nlargest(3, "distance_km")[["nom", "nb_arrets", "distance_km"]]
# Out:
#                             nom  nb_arrets  distance_km
# 1  Agoè Assiyéyé - Grand Marché          9        16.28
# 8            Baguida - Adawlato          8        13.13
# 2             Avédji - Adawlato          9        11.67
